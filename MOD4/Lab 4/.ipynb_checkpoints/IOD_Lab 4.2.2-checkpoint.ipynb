# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# ## Lab 4.2.2: Feature Selection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### 5. Forward Feature Selection
#
# > Forward Selection: Forward selection is an iterative method in which we start with having no feature in the model. In each iteration, we keep adding the feature which best improves our model till an addition of a new variable does not improve the performance of the model.
#
# Create a Regression model using Forward Feature Selection by looping over all the features adding one at a time until there are no improvements on the prediction metric ( R2  and  AdjustedR2  in this case).

# %% [markdown]
# #### 5.1 Load Wine Data & Define Predictor and Target

# %%
## Load the wine quality dataset

# Load the wine dataset from csv
wine = pd.read_csv('../../DATA/winequality_merged.csv')

# define the target variable (dependent variable) as y
y = wine['quality']

# Take all columns except target as predictor columns
predictor_columns = [c for c in wine.columns if c != 'quality']
# Load the dataset as a pandas data frame
X = pd.DataFrame(wine, columns = predictor_columns)

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  red_wine
# 0         9.4        5         1
# 1         9.8        5         1
# 2         9.8        5         1
# 3         9.8        6         1
# 4         9.4        5         1
# ...       ...      ...       ...
# 6492     11.2        6         0
# 6493      9.6        5         0
# 6494      9.4        6         0
# 6495     12.8        7         0
# 6496     11.8        6         0
#
# [6497 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
## Create training and testing subsets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=27)

# %% [markdown]
# #### 5.2 Overview of the code below
#
# The external `while` loop goes forever until there are no improvements to the model, which is controlled by the flag `changed` (until is **not** changed).
# The inner `for` loop goes over each of the features not yet included in the model and calculates the correlation coefficient. If any model improves on the previous best model then the records are updated.
#
# #### Code variables
# - `included`: list of the features (predictors) that were included in the model; starts empty.
# - `excluded`: list of features that have **not** been included in the model; starts as the full list of features.
# - `best`: dictionary to keep record of the best model found at any stage; starts 'empty'.
# - `model`: object of class LinearRegression, with default values for all parameters.
#
# #### Methods of the `LinearRegression` object to investigate
# - `fit()`
# - `fit.score()`
#
# #### Adjusted $R^2$ formula
# $$Adjusted \; R^2 = 1 - { (1 - R^2) (n - 1)  \over n - k - 1 }$$
#
# #### Linear Regression [reference](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression)

# %%
from sklearn.linear_model import LinearRegression

# %%
## Flag intermediate output

show_steps = True   # for testing/debugging
# show_steps = False  # without showing steps

# %%
## Use Forward Feature Selection to pick a good model

# start with no predictors
included = []
# keep track of model and parameters
best = {'feature': '', 'r2': 0, 'a_r2': 0}
# create a model object to hold the modelling parameters
model = LinearRegression() # create a model for Linear Regression
# get the number of cases in the training data
n = X_train.shape[0]

while True:
    changed = False
    
    if show_steps:
        print('') 

    # list the features to be evaluated
    excluded = list(set(X.columns) - set(included))
    
    if show_steps:
        print('(Step) Excluded = %s' % ', '.join(excluded))  

    # for each remaining feature to be evaluated
    for new_column in excluded:
        
        if show_steps:
            print('(Step) Trying %s...' % new_column)
            print('(Step) - Features = %s' % ', '.join(included + [new_column]))

        # fit the model with the Training data
        fit = model.fit(X_train[included + [new_column]], y_train)
        # calculate the score (R^2 for Regression)
        r2 = fit.score(X_train[included + [new_column]], y_train)
        # number of predictors in this model
        k = len(included + [new_column])
        # calculate the adjusted R^2
        adjusted_r2 = 1 - ( ( (1 - r2) * (n - 1) ) / (n - k - 1) )

        if show_steps:
            print('(Step) - Adjusted R^2: This = %.3f; Best = %.3f' % 
                  (adjusted_r2, best['a_r2']))

        # if model improves
        if adjusted_r2 > best['a_r2']:
            # record new parameters
            best = {'feature': new_column, 'r2': r2, 'a_r2': adjusted_r2}
            # flag that found a better model
            changed = True
            if show_steps:
                print('(Step) - New Best!   : Feature = %s; R^2 = %.3f; Adjusted R^2 = %.3f' % 
                      (best['feature'], best['r2'], best['a_r2']))
    # END for

    # if found a better model after testing all remaining features
    if changed:
        # update control details
        included.append(best['feature'])
        excluded = list(set(excluded) - set(best['feature']))
        print('Added feature %-4s with R^2 = %.3f and adjusted R^2 = %.3f' % 
              (best['feature'], best['r2'], best['a_r2']))
    else:
        # terminate if no better model
        break

print('')
print('Resulting features:')
print(', '.join(included))
# Out:
# (Step) Excluded = pH, sulphates, fixed acidity, total sulfur dioxide, citric acid, alcohol, density, chlorides, volatile acidity, free sulfur dioxide, red_wine, residual sugar
# (Step) Trying pH...
# (Step) - Features = pH
# (Step) - Adjusted R^2: This = 0.000; Best = 0.000
# (Step) - New Best!   : Feature = pH; R^2 = 0.001; Adjusted R^2 = 0.000
# (Step) Trying sulphates...
# (Step) - Features = sulphates
# (Step) - Adjusted R^2: This = 0.001; Best = 0.000
# (Step) - New Best!   : Feature = sulphates; R^2 = 0.002; Adjusted R^2 = 0.001
# (Step) Trying fixed acidity...
# (Step) - Features = fixed acidity
# (Step) - Adjusted R^2: This = 0.005; Best = 0.001
# (Step) - New Best!   : Feature = fixed acidity; R^2 = 0.005; Adjusted R^2 = 0.005
# (Step) Trying total sulfur dioxide...
# (Step) - Features = total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.001; Best = 0.005
# (Step) Trying citric acid...
# (Step) - Features = citric acid
# (Step) - Adjusted R^2: This = 0.007; Best = 0.005
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.008; Adjusted R^2 = 0.007
# (Step) Trying alcohol...
# (Step) - Features = alcohol
# (Step) - Adjusted R^2: This = 0.194; Best = 0.007
# (Step) - New Best!   : Feature = alcohol; R^2 = 0.194; Adjusted R^2 = 0.194
# (Step) Trying density...
# (Step) - Features = density
# (Step) - Adjusted R^2: This = 0.090; Best = 0.194
# (Step) Trying chlorides...
# (Step) - Features = chlorides
# (Step) - Adjusted R^2: This = 0.039; Best = 0.194
# (Step) Trying volatile acidity...
# (Step) - Features = volatile acidity
# (Step) - Adjusted R^2: This = 0.071; Best = 0.194
# (Step) Trying free sulfur dioxide...
# (Step) - Features = free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.005; Best = 0.194
# (Step) Trying red_wine...
# (Step) - Features = red_wine
# (Step) - Adjusted R^2: This = 0.014; Best = 0.194
# (Step) Trying residual sugar...
# (Step) - Features = residual sugar
# (Step) - Adjusted R^2: This = 0.001; Best = 0.194
# Added feature alcohol with R^2 = 0.194 and adjusted R^2 = 0.194
#
# (Step) Excluded = pH, sulphates, fixed acidity, total sulfur dioxide, citric acid, density, chlorides, volatile acidity, free sulfur dioxide, red_wine, residual sugar
# (Step) Trying pH...
# (Step) - Features = alcohol, pH
# (Step) - Adjusted R^2: This = 0.195; Best = 0.194
# (Step) - New Best!   : Feature = pH; R^2 = 0.195; Adjusted R^2 = 0.195
# (Step) Trying sulphates...
# (Step) - Features = alcohol, sulphates
# (Step) - Adjusted R^2: This = 0.196; Best = 0.195
# (Step) - New Best!   : Feature = sulphates; R^2 = 0.196; Adjusted R^2 = 0.196
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, fixed acidity
# (Step) - Adjusted R^2: This = 0.195; Best = 0.196
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.201; Best = 0.196
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.201; Adjusted R^2 = 0.201
# (Step) Trying citric acid...
# (Step) - Features = alcohol, citric acid
# (Step) - Adjusted R^2: This = 0.202; Best = 0.201
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.203; Adjusted R^2 = 0.202
# (Step) Trying density...
# (Step) - Features = alcohol, density
# (Step) - Adjusted R^2: This = 0.194; Best = 0.202
# (Step) Trying chlorides...
# (Step) - Features = alcohol, chlorides
# (Step) - Adjusted R^2: This = 0.201; Best = 0.202
# (Step) Trying volatile acidity...
# (Step) - Features = alcohol, volatile acidity
# (Step) - Adjusted R^2: This = 0.256; Best = 0.202
# (Step) - New Best!   : Feature = volatile acidity; R^2 = 0.256; Adjusted R^2 = 0.256
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.218; Best = 0.256
# (Step) Trying red_wine...
# (Step) - Features = alcohol, red_wine
# (Step) - Adjusted R^2: This = 0.205; Best = 0.256
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, residual sugar
# (Step) - Adjusted R^2: This = 0.210; Best = 0.256
# Added feature volatile acidity with R^2 = 0.256 and adjusted R^2 = 0.256
#
# (Step) Excluded = pH, sulphates, fixed acidity, total sulfur dioxide, citric acid, density, chlorides, free sulfur dioxide, red_wine, residual sugar
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, pH
# (Step) - Adjusted R^2: This = 0.258; Best = 0.256
# (Step) - New Best!   : Feature = pH; R^2 = 0.258; Adjusted R^2 = 0.258
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, sulphates
# (Step) - Adjusted R^2: This = 0.266; Best = 0.258
# (Step) - New Best!   : Feature = sulphates; R^2 = 0.266; Adjusted R^2 = 0.266
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, fixed acidity
# (Step) - Adjusted R^2: This = 0.257; Best = 0.266
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.257; Best = 0.266
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, citric acid
# (Step) - Adjusted R^2: This = 0.256; Best = 0.266
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, density
# (Step) - Adjusted R^2: This = 0.264; Best = 0.266
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, chlorides
# (Step) - Adjusted R^2: This = 0.256; Best = 0.266
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.260; Best = 0.266
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, red_wine
# (Step) - Adjusted R^2: This = 0.261; Best = 0.266
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, residual sugar
# (Step) - Adjusted R^2: This = 0.262; Best = 0.266
# Added feature sulphates with R^2 = 0.266 and adjusted R^2 = 0.266
#
# (Step) Excluded = pH, fixed acidity, total sulfur dioxide, citric acid, density, chlorides, free sulfur dioxide, red_wine, residual sugar
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, pH
# (Step) - Adjusted R^2: This = 0.267; Best = 0.266
# (Step) - New Best!   : Feature = pH; R^2 = 0.267; Adjusted R^2 = 0.267
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, fixed acidity
# (Step) - Adjusted R^2: This = 0.266; Best = 0.267
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.266; Best = 0.267
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, citric acid
# (Step) - Adjusted R^2: This = 0.266; Best = 0.267
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, density
# (Step) - Adjusted R^2: This = 0.270; Best = 0.267
# (Step) - New Best!   : Feature = density; R^2 = 0.270; Adjusted R^2 = 0.270
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, chlorides
# (Step) - Adjusted R^2: This = 0.267; Best = 0.270
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.272; Best = 0.270
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.273; Adjusted R^2 = 0.272
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, sulphates, red_wine
# (Step) - Adjusted R^2: This = 0.267; Best = 0.272
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar
# (Step) - Adjusted R^2: This = 0.275; Best = 0.272
# (Step) - New Best!   : Feature = residual sugar; R^2 = 0.275; Adjusted R^2 = 0.275
# Added feature residual sugar with R^2 = 0.275 and adjusted R^2 = 0.275
#
# (Step) Excluded = pH, fixed acidity, total sulfur dioxide, citric acid, density, chlorides, free sulfur dioxide, red_wine
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, pH
# (Step) - Adjusted R^2: This = 0.276; Best = 0.275
# (Step) - New Best!   : Feature = pH; R^2 = 0.277; Adjusted R^2 = 0.276
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, fixed acidity
# (Step) - Adjusted R^2: This = 0.274; Best = 0.276
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.277; Best = 0.276
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.277; Adjusted R^2 = 0.277
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, citric acid
# (Step) - Adjusted R^2: This = 0.275; Best = 0.277
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, density
# (Step) - Adjusted R^2: This = 0.274; Best = 0.277
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, chlorides
# (Step) - Adjusted R^2: This = 0.275; Best = 0.277
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.277; Best = 0.277
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.278; Adjusted R^2 = 0.277
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine
# (Step) - Adjusted R^2: This = 0.278; Best = 0.277
# (Step) - New Best!   : Feature = red_wine; R^2 = 0.279; Adjusted R^2 = 0.278
# Added feature red_wine with R^2 = 0.279 and adjusted R^2 = 0.278
#
# (Step) Excluded = pH, fixed acidity, total sulfur dioxide, citric acid, density, chlorides, free sulfur dioxide
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, pH
# (Step) - Adjusted R^2: This = 0.279; Best = 0.278
# (Step) - New Best!   : Feature = pH; R^2 = 0.280; Adjusted R^2 = 0.279
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, fixed acidity
# (Step) - Adjusted R^2: This = 0.278; Best = 0.279
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.278; Best = 0.279
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, citric acid
# (Step) - Adjusted R^2: This = 0.279; Best = 0.279
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density
# (Step) - Adjusted R^2: This = 0.281; Best = 0.279
# (Step) - New Best!   : Feature = density; R^2 = 0.282; Adjusted R^2 = 0.281
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, chlorides
# (Step) - Adjusted R^2: This = 0.279; Best = 0.281
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.283; Best = 0.281
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.284; Adjusted R^2 = 0.283
# Added feature free sulfur dioxide with R^2 = 0.284 and adjusted R^2 = 0.283
#
# (Step) Excluded = pH, fixed acidity, total sulfur dioxide, citric acid, density, chlorides
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, pH
# (Step) - Adjusted R^2: This = 0.284; Best = 0.283
# (Step) - New Best!   : Feature = pH; R^2 = 0.285; Adjusted R^2 = 0.284
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, fixed acidity
# (Step) - Adjusted R^2: This = 0.283; Best = 0.284
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.287; Best = 0.284
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.288; Adjusted R^2 = 0.287
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, citric acid
# (Step) - Adjusted R^2: This = 0.284; Best = 0.287
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, density
# (Step) - Adjusted R^2: This = 0.285; Best = 0.287
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, chlorides
# (Step) - Adjusted R^2: This = 0.284; Best = 0.287
# Added feature total sulfur dioxide with R^2 = 0.288 and adjusted R^2 = 0.287
#
# (Step) Excluded = pH, fixed acidity, citric acid, density, chlorides
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide, pH
# (Step) - Adjusted R^2: This = 0.288; Best = 0.287
# (Step) - New Best!   : Feature = pH; R^2 = 0.289; Adjusted R^2 = 0.288
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide, fixed acidity
# (Step) - Adjusted R^2: This = 0.287; Best = 0.288
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide, citric acid
# (Step) - Adjusted R^2: This = 0.288; Best = 0.288
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide, density
# (Step) - Adjusted R^2: This = 0.289; Best = 0.288
# (Step) - New Best!   : Feature = density; R^2 = 0.290; Adjusted R^2 = 0.289
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide, chlorides
# (Step) - Adjusted R^2: This = 0.288; Best = 0.289
# Added feature density with R^2 = 0.290 and adjusted R^2 = 0.289
#
# (Step) Excluded = pH, citric acid, chlorides, fixed acidity
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide, density, pH
# (Step) - Adjusted R^2: This = 0.290; Best = 0.289
# (Step) - New Best!   : Feature = pH; R^2 = 0.291; Adjusted R^2 = 0.290
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide, density, citric acid
# (Step) - Adjusted R^2: This = 0.289; Best = 0.290
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide, density, chlorides
# (Step) - Adjusted R^2: This = 0.290; Best = 0.290
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide, density, fixed acidity
# (Step) - Adjusted R^2: This = 0.289; Best = 0.290
# Added feature pH   with R^2 = 0.291 and adjusted R^2 = 0.290
#
# (Step) Excluded = citric acid, chlorides, fixed acidity
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide, density, pH, citric acid
# (Step) - Adjusted R^2: This = 0.290; Best = 0.290
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide, density, pH, chlorides
# (Step) - Adjusted R^2: This = 0.291; Best = 0.290
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.292; Adjusted R^2 = 0.291
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide, density, pH, fixed acidity
# (Step) - Adjusted R^2: This = 0.294; Best = 0.291
# (Step) - New Best!   : Feature = fixed acidity; R^2 = 0.296; Adjusted R^2 = 0.294
# Added feature fixed acidity with R^2 = 0.296 and adjusted R^2 = 0.294
#
# (Step) Excluded = citric acid, chlorides
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide, density, pH, fixed acidity, citric acid
# (Step) - Adjusted R^2: This = 0.294; Best = 0.294
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.296; Adjusted R^2 = 0.294
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide, density, pH, fixed acidity, chlorides
# (Step) - Adjusted R^2: This = 0.295; Best = 0.294
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.296; Adjusted R^2 = 0.295
# Added feature chlorides with R^2 = 0.296 and adjusted R^2 = 0.295
#
# (Step) Excluded = citric acid
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide, density, pH, fixed acidity, chlorides, citric acid
# (Step) - Adjusted R^2: This = 0.295; Best = 0.295
#
# Resulting features:
# alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide, total sulfur dioxide, density, pH, fixed acidity, chlorides

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2023 Institute of Data
#
#
# ---
#
#
#
# ---
