# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 2.2.1

# %% [markdown]
# # Data
#
# > The sinking of the RMS Titanic is one of the most infamous shipwrecks in history.  On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# > One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper-class.
#
# In this lab, we'll explore this dataset to find insight.
#
# [Titanic Dataset](https://www.kaggle.com/c/titanic/data)

# %% [markdown]
# # Data Dictionary
#
# | Variable |                                 Definition | Key                                            |
# |----------|-------------------------------------------:|------------------------------------------------|
# | Survival | Survival                                   | 0 = No, 1 = Yes                                |
# | Pclass   | Ticket class                               | 1 = 1st, 2 = 2nd, 3 = 3rd                      |
# | Sex      | Sex                                        |                                                |
# | Age      | Age in years                               |                                                |
# | SibSp    | # of siblings / spouses aboard the Titanic |                                                |
# | Parch    | # of parents / children aboard the Titanic |                                                |
# | Ticket   | Ticket number                              |                                                |
# | Fare     | Passenger fare                             |                                                |
# | Cabin    | Cabin number                               |                                                |
# | Embarked | Port of Embarkation                        | C = Cherbourg, Q = Queenstown, S = Southampton |

# %% [markdown]
# # Loading Modules

# %%
# Load necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Loading Dataset
#
# Read titanic dataset.

# %%
# Read Titanic Dataset
titanic_csv = '../../DATA/titanic_train.csv'
titanic = pd.read_csv(titanic_csv)

# %% [markdown]
# # Explore Dataset

# %% [markdown]
# ## Head

# %%
# Check Head
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Tail

# %%
# Check Tail
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## Shape
#
# Find shape of dataset.

# %%
# ANSWER
titanic.shape
# Out:
# (891, 12)

# %% [markdown]
# ## Check Types of Data
#
# Check types of data you have

# %%
# ANSWER
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## Check Null Values
#
# Check whether dataset have any null values.

# %%
# ANSWER
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Check titanic data again
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Fill Null Values
#
# Is there any null values in any columns?
#
# - Identify those columns
# - Fill those null values using your own logic
#     - State your logic behind every step

# %% [markdown]
# ### Age

# %%
# ANSWER
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Check average age by Pclass and Sex combinations
titanic.groupby(by=['Pclass', 'Sex'])['Age'].mean()
# Out:
# Pclass  Sex
# 1       female    34.611765
#         male      41.281386
# 2       female    28.722973
#         male      30.740707
# 3       female    21.750000
#         male      26.507589
# Name: Age, dtype: float64

# %%
# Replace missing values of 'Age' column with the average age by 'Pclass' & 'Sex'
titanic['Age'].fillna(titanic.groupby(by=['Pclass', 'Sex'])['Age'].transform('mean'), inplace=True)
# Check missing values of 'Age' column
titanic['Age'].isna().sum()
titanic['Age']
# Out:
# 0      22.00
# 1      38.00
# 2      26.00
# 3      35.00
# 4      35.00
#        ...
# 886    27.00
# 887    19.00
# 888    21.75
# 889    26.00
# 890    32.00
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# ### Cabin

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  26.507589
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# 7                     Palsson, Master. Gosta Leonard    male   2.000000
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      1      0            113803  53.1000  C123        S
# 4      0      0            373450   8.0500   NaN        S
# 5      0      0            330877   8.4583   NaN        Q
# 6      0      0             17463  51.8625   E46        S
# 7      3      1            349909  21.0750   NaN        S
# 8      0      2            347742  11.1333   NaN        S
# 9      1      0            237736  30.0708   NaN        C

# %%
# Check unique values of 'Cabin'
titanic['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148'], dtype=object)

# %%
# Create a new column for cabin class
titanic['Cabin_class'] = titanic['Cabin'].str[0]
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00      1
# 2                               Heikkinen, Miss. Laina  female  26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1
# 4                             Allen, Mr. William Henry    male  35.00      0
# ..                                                 ...     ...    ...    ...
# 886                              Montvila, Rev. Juozas    male  27.00      0
# 887                       Graham, Miss. Margaret Edith  female  19.00      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  21.75      1
# 889                              Behr, Mr. Karl Howell    male  26.00      0
# 890                                Dooley, Mr. Patrick    male  32.00      0
#
#      Parch            Ticket     Fare Cabin Embarked Cabin_class
# 0        0         A/5 21171   7.2500   NaN        S         NaN
# 1        0          PC 17599  71.2833   C85        C           C
# 2        0  STON/O2. 3101282   7.9250   NaN        S         NaN
# 3        0            113803  53.1000  C123        S           C
# 4        0            373450   8.0500   NaN        S         NaN
# ..     ...               ...      ...   ...      ...         ...
# 886      0            211536  13.0000   NaN        S         NaN
# 887      0            112053  30.0000   B42        S           B
# 888      2        W./C. 6607  23.4500   NaN        S         NaN
# 889      0            111369  30.0000  C148        C           C
# 890      0            370376   7.7500   NaN        Q         NaN
#
# [891 rows x 13 columns]

# %%
# Check the frequencies of 'Cabin_class' by 'Embarked' & 'Pclass'
titanic.groupby(by=['Pclass', 'Cabin_class']).size().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
# ANSWER
# Transform values of 'Cabin_class' into numbers
cabin_map = {
    'A': 1
    , 'B': 2
    , 'C': 3
    , 'D': 4
    , 'E': 5
    , 'F': 6
    , 'G': 7
    , 'T': 8
}
titanic['Cabin_transformed'] = titanic['Cabin_class'].map(cabin_map)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00      1
# 2                               Heikkinen, Miss. Laina  female  26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1
# 4                             Allen, Mr. William Henry    male  35.00      0
# ..                                                 ...     ...    ...    ...
# 886                              Montvila, Rev. Juozas    male  27.00      0
# 887                       Graham, Miss. Margaret Edith  female  19.00      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  21.75      1
# 889                              Behr, Mr. Karl Howell    male  26.00      0
# 890                                Dooley, Mr. Patrick    male  32.00      0
#
#      Parch            Ticket     Fare Cabin Embarked Cabin_class  \
# 0        0         A/5 21171   7.2500   NaN        S         NaN
# 1        0          PC 17599  71.2833   C85        C           C
# 2        0  STON/O2. 3101282   7.9250   NaN        S         NaN
# 3        0            113803  53.1000  C123        S           C
# 4        0            373450   8.0500   NaN        S         NaN
# ..     ...               ...      ...   ...      ...         ...
# 886      0            211536  13.0000   NaN        S         NaN
# 887      0            112053  30.0000   B42        S           B
# 888      2        W./C. 6607  23.4500   NaN        S         NaN
# 889      0            111369  30.0000  C148        C           C
# 890      0            370376   7.7500   NaN        Q         NaN
#
#      Cabin_transformed
# 0                  NaN
# 1                  3.0
# 2                  NaN
# 3                  3.0
# 4                  NaN
# ..                 ...
# 886                NaN
# 887                2.0
# 888                NaN
# 889                3.0
# 890                NaN
#
# [891 rows x 14 columns]

# %%
# Fill missing values with the average of 'Cabin_transformed'
titanic['Cabin_transformed'].fillna(titanic.groupby(by=['Pclass'])['Cabin_transformed'].transform('mean'), inplace=True)
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  26.507589
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# 7                     Palsson, Master. Gosta Leonard    male   2.000000
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked Cabin_class  \
# 0      1      0         A/5 21171   7.2500   NaN        S         NaN
# 1      1      0          PC 17599  71.2833   C85        C           C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S         NaN
# 3      1      0            113803  53.1000  C123        S           C
# 4      0      0            373450   8.0500   NaN        S         NaN
# 5      0      0            330877   8.4583   NaN        Q         NaN
# 6      0      0             17463  51.8625   E46        S           E
# 7      3      1            349909  21.0750   NaN        S         NaN
# 8      0      2            347742  11.1333   NaN        S         NaN
# 9      1      0            237736  30.0708   NaN        C         NaN
#
#    Cabin_transformed
# 0           6.083333
# 1           3.000000
# 2           6.083333
# 3           3.000000
# 4           6.083333
# 5           6.083333
# 6           5.000000
# 7           6.083333
# 8           6.083333
# 9           5.250000

# %%
# Remove decimals in 'Cabin_transformed'
titanic['Cabin_transformed'] = titanic['Cabin_transformed'].round(decimals=0)
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  26.507589
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# 7                     Palsson, Master. Gosta Leonard    male   2.000000
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked Cabin_class  \
# 0      1      0         A/5 21171   7.2500   NaN        S         NaN
# 1      1      0          PC 17599  71.2833   C85        C           C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S         NaN
# 3      1      0            113803  53.1000  C123        S           C
# 4      0      0            373450   8.0500   NaN        S         NaN
# 5      0      0            330877   8.4583   NaN        Q         NaN
# 6      0      0             17463  51.8625   E46        S           E
# 7      3      1            349909  21.0750   NaN        S         NaN
# 8      0      2            347742  11.1333   NaN        S         NaN
# 9      1      0            237736  30.0708   NaN        C         NaN
#
#    Cabin_transformed
# 0                6.0
# 1                3.0
# 2                6.0
# 3                3.0
# 4                6.0
# 5                6.0
# 6                5.0
# 7                6.0
# 8                6.0
# 9                5.0

# %% [markdown]
# ### Embarked

# %%
# Check rows with missing values in 'Embarked'
titanic[titanic['Embarked'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked Cabin_class  \
# 61   female  38.0      0      0  113572  80.0   B28      NaN           B
# 829  female  62.0      0      0  113572  80.0   B28      NaN           B
#
#      Cabin_transformed
# 61                 2.0
# 829                2.0

# %%
# Check counts of 'Cabin_transformed' & 'Embarked'
titanic.groupby(by=['Embarked', 'Cabin_transformed']).size()
# Out:
# Embarked  Cabin_transformed
# C         1.0                    7
#           2.0                   22
#           3.0                   40
#           4.0                   13
#           5.0                   20
#           6.0                   66
# Q         3.0                    2
#           5.0                    3
#           6.0                   72
# S         1.0                    8
#           2.0                   23
#           3.0                   57
#           4.0                   20
#           5.0                  177
#           6.0                  354
#           7.0                    4
#           8.0                    1
# dtype: int64

# %%
# Examine 'Embarked' and 'Ticket'
titanic.loc[titanic['Embarked'] == 'Q', 'Ticket'].unique()
# Out:
# array(['330877', '382652', '330923', '330959', '335677', '330958',
#        '370371', '14311', '330932', '371110', '370369', '370372',
#        '365222', '35851', '370365', '364849', '368703', '370370',
#        '367231', '367229', '367230', '19928', '384461', '382649',
#        '370375', '336439', '370373', '9234', '367226', '226593', '234818',
#        '330931', '330980', '14313', '367655', '394140', 'A/5. 13032',
#        '364851', '371060', '36209', '364846', '330909', '382651',
#        '367232', '330979', '372622', '14312', '364848', '370377',
#        '219533', '334912', '330919', '365226', '330935', '35852', '36864',
#        '36568', '36866', '335097', '364850', '383121', '36865', '12460',
#        '368323', '367228', '370376'], dtype=object)

# %%
titanic.loc[titanic['Embarked'] == 'C', 'Ticket'].unique()
# Out:
# array(['PC 17599', '237736', '2649', '2631', 'PC 17601', 'PC 17569',
#        'PC 17604', '2677', '2651', '349253', 'SC/Paris 2123', '2662',
#        'PC 17572', '113509', '2697', '2669', 'PC 17605', '2661', '2680',
#        'PC 17754', 'PC 17759', '2665', '2627', 'PC 17558', '2668',
#        '349241', 'SC/PARIS 2133', 'PC 17593', '2678', 'PC 17597', '17764',
#        'PC 17595', 'SC/PARIS 2131', 'PC 17610', '2628', '2699', '112277',
#        '35273', '11813', '2694', '2650', 'PC 17585', 'PC 17755',
#        'PC 17596', '349239', '11967', 'SC/Paris 2163', 'PC 17612', '2693',
#        '17421', 'PC 17758', 'P/PP 3381', 'PC 17485', '11767', 'PC 17608',
#        '16966', 'PC 17760', '111361', '2695', '2647', 'SC/PARIS 2167',
#        '2691', '110813', '2626', 'PC 17477', '11765', '113503', '2648',
#        'PC 17757', '2653', 'SC 1748', '349254', '2666', '113051', '17453',
#        '349240', 'SC/AH Basle 541', '11771', 'PC 17609', '36947',
#        'PC 17603', '2624', '2700', '2641', '2690', 'PC 17761', '13568',
#        'SC/PARIS 2146', '2620', '11755', '2686', '2689', '13049', '3411',
#        '13567', '2664', '111426', '2659', '13214', '13213', '2623',
#        '349256', '2672', 'PC 17482', '2663', '112379', '2674', '2687',
#        'PC 17600', '2685', '2625', 'S.C./PARIS 2079', '2671', 'PC 17756',
#        '11774', '113798', '2683', '349213', '2629', 'SC/PARIS 2149',
#        '2667', '111369'], dtype=object)

# %%
titanic.loc[titanic['Embarked'] == 'S', 'Ticket'].unique()
# Out:
# array(['A/5 21171', 'STON/O2. 3101282', '113803', '373450', '17463',
#        '349909', '347742', 'PP 9549', '113783', 'A/5. 2151', '347082',
#        '350406', '248706', '244373', '345763', '239865', '248698',
#        '113788', '347077', '19950', '349216', 'C.A. 24579', '113789',
#        'A./5. 2152', '345764', '7546', '11668', 'S.C./A.4. 23567',
#        '349237', '3101295', 'A/4. 39886', '2926', '19947', 'C.A. 31026',
#        'C.A. 34651', 'CA 2144', '36973', '347088', 'C.A. 29395',
#        'S.P. 3464', '3101281', '315151', 'C.A. 33111', 'S.O.C. 14879',
#        '1601', '348123', '349208', '374746', '248738', '364516', '345767',
#        '345779', '113059', 'SO/C 14885', '3101278', 'W./C. 6608',
#        'SOTON/OQ 392086', '343275', '343276', '347466', 'W.E.P. 5734',
#        'C.A. 2315', '364500', '374910', '231919', '244367', '349245',
#        '349215', '35281', '7540', '3101276', '349207', '343120', '312991',
#        '349249', '110465', '324669', '4136', 'STON/O 2. 3101294',
#        'A4. 54510', '27267', 'C 17369', '347061', 'SOTON/O.Q. 3101307',
#        'A/5. 3337', '228414', 'C.A. 29178', '11752', '7534', '347081',
#        'STON/O2. 3101279', '231945', 'C.A. 33112', '350043', '230080',
#        '244310', 'S.O.P. 1166', '113776', 'A.5. 11206', 'A/5. 851',
#        'Fa 265302', 'SOTON/OQ 392090', '315037', 'CA. 2343', '371362',
#        'C.A. 33595', '347068', '315093', '363291', '113505', 'PC 17318',
#        '111240', 'STON/O 2. 3101280', '350404', '4133', '250653', 'LINE',
#        '230136', '315153', '113767', '111428', '349247', '234604',
#        '28424', '350046', '4579', '248747', '345770', '3101264',
#        'A/5 3540', '347054', 'SOTON/O.Q. 3101311', 'F.C.C. 13528',
#        'A/5 21174', '250646', 'STON/O2. 3101283', '243847', 'W/C 14208',
#        'SOTON/OQ 392089', '220367', '21440', '349234', '19943', 'PP 4348',
#        'SW/PP 751', 'A/5 21173', '236171', '347067', '237442',
#        'C.A. 29566', 'W./C. 6609', '26707', 'C.A. 31921', '28665',
#        'SCO/W 1585', 'W./C. 14263', 'STON/O 2. 3101275', '347071',
#        '250649', '11751', '244252', '362316', '113514', 'A/5. 3336',
#        '370129', '110152', '230433', '110413', '112059', 'C.A. 17248',
#        '347083', 'PC 17582', 'PC 17760', '113798', '250644', '13502',
#        '347073', '239853', 'C.A. 2673', '347464', '345778', 'A/5. 10482',
#        '113056', '345774', '349206', '237798', '19877', '349236',
#        '349233', '113781', '19988', 'A/5 2466', '250651', '349243',
#        'F.C.C. 13529', '347470', '29011', '36928', 'A/5 21172', '349219',
#        '345364', '28551', '113043', 'PC 17611', '349225', '7598',
#        '113784', '248740', '244361', '229236', '248733', '31418',
#        '386525', 'C.A. 37671', '315088', '7267', '113510', '345783',
#        '237671', 'SOTON/O.Q. 3101310', 'C 7076', '3101267', '323951',
#        'C 7077', '347069', 'STON/O 2. 3101293', '349227', '27849',
#        '113760', '350034', '3101277', '350052', '350407', '28403',
#        '244278', '240929', 'STON/O 2. 3101289', '341826', '4137',
#        '315096', '28664', '347064', '29106', '312992', '349222',
#        'STON/O 2. 3101269', '343095', '28220', '250652', '28228',
#        '345773', '315082', '347080', 'A/4. 34244', '2003', '250655',
#        'SOTON/O.Q. 392078', '110564', '376564', 'SC/AH 3085',
#        'STON/O 2. 3101274', '13507', 'C.A. 18723', '345769', '347076',
#        '230434', '65306', '33638', '113794', '113786', '65303',
#        'A/5 2817', '13509', '17464', 'F.C.C. 13531', '19952', '364506',
#        '111320', '234360', 'A/S 2816', 'SOTON/O.Q. 3101306', '113792',
#        '323592', '315089', '7553', '31027', '3460', '350060', '3101298',
#        '239854', 'A/5 3594', '4134', 'A.5. 18509', '65304',
#        'SOTON/OQ 3101317', '113787', 'A/4 45380', 'C.A. 6212', '350035',
#        '315086', '4135', '26360', '111427', 'C 4001', 'SOTON/OQ 3101316',
#        'PC 17473', '349209', '36967', 'C.A. 34260', '226875', '349242',
#        '12749', '349252', 'W./C. 14258', 'PC 17483', '3101296', '29104',
#        '315084', '113050', '364498', 'WE/P 5735', '2908', '693', '244358',
#        '347085', '113807', '345572', '349251', '218629',
#        'SOTON/OQ 392082', 'SOTON/O.Q. 392087', 'A/4 48871', '349205',
#        '350417', 'S.W./PP 752', '11769', 'PC 17474', 'A/4. 20589',
#        '358585', '243880', 'STON/O 2. 3101286', '237789', '237565',
#        '14973', 'A./5. 3235', 'STON/O 2. 3101273', 'A/5 3902',
#        'SC/AH 29037', '248727', '349214', '113796', '364511', '349910',
#        '349246', '113804', 'SOTON/O.Q. 3101305', '364512', '220845',
#        '31028', '11753', '350029', '54636', '36963', '349224', '27042',
#        '347743', '112052', '237668', 'STON/O 2. 3101292', '350050',
#        '349231', 'S.O./P.P. 751', 'CA. 2314', '349221', '8475', '349223',
#        '29751', '5727', '349210', 'STON/O 2. 3101285', '234686', '312993',
#        'A/5 3536', '19996', '29750', 'F.C. 12750', 'C.A. 24580', '244270',
#        '239856', '349912', '342826', '4138', '6563', '349228', '350036',
#        '24160', '17474', '113800', '248731', '363592', '348121',
#        'PC 17475', '350025', '223596', 'PC 17476', '113028', '7545',
#        '250647', '348124', '34218', '347062', '350048', '12233', '250643',
#        '113806', '315094', '236853', 'STON/O2. 3101271', '239855',
#        '28425', '233639', '349201', '349218', '16988', '376566',
#        'STON/O 2. 3101288', '250648', '113773', '29103', '392096',
#        '345780', '349204', '350042', '29108', '363294',
#        'SOTON/O2 3101272', '347074', '8471', '345781', '350047',
#        'S.O./P.P. 3', '29105', '347078', '113501', 'W./C. 6607',
#        'SOTON/O.Q. 3101312', '374887', '3101265', '349203', '28213',
#        '17465', '349244', '347089', '347063', '112050', '347087',
#        '248723', '3474', '28206', '364499', '112058', 'STON/O2. 3101290',
#        'C 7075', '315098', '19972', '347468', '2223', '315097', '392092',
#        'SOTON/O2 3101287', '315090', 'C.A. 5547', '347060', 'PC 17592',
#        '392091', '113055', '350026', '28134', '17466', '233866', '236852',
#        'PC 17590', '345777', '349248', '695', '345765', '349212',
#        '349217', '349257', '7552', 'C.A./SOTON 34068', 'SOTON/OQ 392076',
#        '211536', '112053'], dtype=object)

# %%
# ANSWER
"""
Since there is no clear patterns between 'Embarked' & the other columns
Plus the no. of missing values in 'Embarked' is small (2), we can remove these missing values from the data set.
"""
titanic.dropna(how='any', inplace=True)
titanic['Embarked'].isna().sum()
# Out:
# 0

# %% [markdown]
# # Describe
#
# Describe your dataset.

# %%
# ANSWER
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   202.000000  202.000000  202.000000  202.000000  202.000000
# mean    455.495050    0.663366    1.198020   35.804726    0.445545
# std     249.704228    0.473732    0.528205   14.998381    0.630490
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.250000    0.000000    1.000000   25.000000    0.000000
# 50%     457.500000    1.000000    1.000000   36.000000    0.000000
# 75%     681.500000    1.000000    1.000000   46.750000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare  Cabin_transformed
# count  202.000000  202.000000         202.000000
# mean     0.440594   76.103301           3.405941
# std      0.732294   74.759941           1.477380
# min      0.000000    0.000000           1.000000
# 25%      0.000000   28.959375           2.000000
# 50%      0.000000   55.000000           3.000000
# 75%      1.000000   89.776050           4.000000
# max      4.000000  512.329200           8.000000

# %% [markdown]
# # Relationship between Features and Survival
#
# Find relationship between categorical features and survived.
#
# **Describe your findings.**

# %%
def bar_charts(df, feature):
    '''
    Inputs:
    df: Dataset
    feature: Name of Feature to Check With Survived
    '''
    _agg = {
        'PassengerId': 'count'
    }
    _groupby = ['Survived', feature]

    df_feature = df.groupby(by=_groupby).agg(_agg)

    ax = df_feature.unstack().plot(kind='bar', figsize=(15,6))
    plt.legend(list(df_feature.index.levels[1].unique()))
    plt.xlabel('Survived')
    plt.xticks(np.arange(2), ('No', 'Yes'))
    plt.show();

# %%
titanic.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
# 23           24         1       1
# 27           28         0       1
# 31           32         1       1
# 52           53         1       1
#
#                                                  Name     Sex        Age  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 6                             McCarthy, Mr. Timothy J    male  54.000000
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.000000
# 11                           Bonnell, Miss. Elizabeth  female  58.000000
# 21                              Beesley, Mr. Lawrence    male  34.000000
# 23                       Sloper, Mr. William Thompson    male  28.000000
# 27                     Fortune, Mr. Charles Alexander    male  19.000000
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female  34.611765
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.000000
#
#     SibSp  Parch    Ticket      Fare        Cabin Embarked Cabin_class  \
# 1       1      0  PC 17599   71.2833          C85        C           C
# 3       1      0    113803   53.1000         C123        S           C
# 6       0      0     17463   51.8625          E46        S           E
# 10      1      1   PP 9549   16.7000           G6        S           G
# 11      0      0    113783   26.5500         C103        S           C
# 21      0      0    248698   13.0000          D56        S           D
# 23      0      0    113788   35.5000           A6        S           A
# 27      3      2     19950  263.0000  C23 C25 C27        S           C
# 31      1      0  PC 17569  146.5208          B78        C           B
# 52      1      0  PC 17572   76.7292          D33        C           D
#
#     Cabin_transformed
# 1                 3.0
# 3                 3.0
# 6                 5.0
# 10                7.0
# 11                3.0
# 21                4.0
# 23                1.0
# 27                3.0
# 31                2.0
# 52                4.0

# %% [markdown]
# ## Pclass
#
# Use the `bar_charts` function above to view the relationship between survived and pclass.  Note your findings.

# %%
titanic.groupby(by=['Pclass']).size()
# Out:
# Pclass
# 1    174
# 2     16
# 3     12
# dtype: int64

# %%
# ANSWER
bar_charts(titanic, 'Pclass')

# %% [markdown]
# ## Sex
#
# Use `bar_charts` to view the relationship between survived and sex.  Note your findings.

# %%
titanic.groupby(by=['Sex']).size()
# Out:
# Sex
# female     95
# male      107
# dtype: int64

# %%
# ANSWER
bar_charts(titanic, 'Sex')

# %% [markdown]
# ## Parch
#
# Parch = Number of parents and children travelling with each passenger. Use `bar_charts` to view the relationship between survived and Parch.

# %%
# ANSWER
bar_charts(titanic, 'Parch')

# %% [markdown]
# ## SibSp
#
# SibSp = Number of siblings and spouses travelling with each passenger. Use `bar_charts` to view the relationship between survived and SibSp.

# %%
# ANSWER
bar_charts(titanic, 'SibSp')

# %% [markdown]
# ## Embarked
#
# Do the same for the Embarked variable.

# %%
# ANSWER
bar_charts(titanic, 'Embarked')

# %% [markdown]
# # Feature Engineering
#
# We shall create some new features from the existing features.

# %% [markdown]
# ## Fare Class
#
# Create a new column 'Fare class' based on their fare as defined below. Is there any relationship between fare and survival?

# %%
def create_fare_class(x):
    if x > 30:
        fare_class = 1
    elif x > 20 and x <= 30:
        fare_class = 2
    elif x > 10 and x <= 20:
        fare_class = 3
    else:
        fare_class = 4
    return fare_class

# %%
titanic['Fare'].unique()
# Out:
# array([ 71.2833,  53.1   ,  51.8625,  16.7   ,  26.55  ,  13.    ,
#         35.5   , 263.    , 146.5208,  76.7292,  61.9792,  83.475 ,
#         10.5   ,   7.65  ,  61.175 ,  34.6542,  63.3583,  77.2875,
#         52.    , 247.5208,  22.3583,  26.2833,  79.2   ,  26.    ,
#         66.6   ,  55.    ,  33.5   ,  30.6958,  28.7125,  39.    ,
#         50.    ,  27.7208,  10.4625,  31.    , 113.275 ,  76.2917,
#         90.    ,  52.5542,  86.5   ,  79.65  ,   0.    , 153.4625,
#        135.6333,  29.7   ,  77.9583,  91.0792,  12.875 , 151.55  ,
#         30.5   ,  12.35  , 108.9   ,  56.9292,  83.1583, 262.375 ,
#        164.8667, 134.5   ,  57.9792,  28.5   ,  35.    ,  75.25  ,
#         69.3   ,  55.4417, 211.5   , 120.    ,   8.05  ,  55.9   ,
#         81.8583,  27.75  ,  89.1042,  38.5   ,  13.7917,  78.2667,
#         26.2875,  34.0208,  93.5   , 221.7792,  49.5   ,  71.    ,
#        106.425 , 110.8833,  39.6   ,  51.4792,  26.3875,  40.125 ,
#         32.3208,  30.    ,  25.5875, 512.3292, 211.3375,  57.    ,
#        227.525 ,  49.5042,  78.85  ,  12.475 ,   7.75  ,  25.9292,
#         39.4   ,  50.4958,   5.    ])

# %%
titanic['Fare'].dtypes
# Out:
# dtype('float64')

# %%
# ANSWER
titanic['Fare_class'] = titanic['Fare'].apply(create_fare_class)
titanic.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
# 23           24         1       1
# 27           28         0       1
# 31           32         1       1
# 52           53         1       1
#
#                                                  Name     Sex        Age  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 6                             McCarthy, Mr. Timothy J    male  54.000000
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.000000
# 11                           Bonnell, Miss. Elizabeth  female  58.000000
# 21                              Beesley, Mr. Lawrence    male  34.000000
# 23                       Sloper, Mr. William Thompson    male  28.000000
# 27                     Fortune, Mr. Charles Alexander    male  19.000000
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female  34.611765
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.000000
#
#     SibSp  Parch    Ticket      Fare        Cabin Embarked Cabin_class  \
# 1       1      0  PC 17599   71.2833          C85        C           C
# 3       1      0    113803   53.1000         C123        S           C
# 6       0      0     17463   51.8625          E46        S           E
# 10      1      1   PP 9549   16.7000           G6        S           G
# 11      0      0    113783   26.5500         C103        S           C
# 21      0      0    248698   13.0000          D56        S           D
# 23      0      0    113788   35.5000           A6        S           A
# 27      3      2     19950  263.0000  C23 C25 C27        S           C
# 31      1      0  PC 17569  146.5208          B78        C           B
# 52      1      0  PC 17572   76.7292          D33        C           D
#
#     Cabin_transformed  Fare_class
# 1                 3.0           1
# 3                 3.0           1
# 6                 5.0           1
# 10                7.0           3
# 11                3.0           2
# 21                4.0           3
# 23                1.0           1
# 27                3.0           1
# 31                2.0           1
# 52                4.0           1

# %% [markdown]
# ## Age Class
#
# Similarly, create a new column 'Age class' based on their age as defined below.

# %%
def create_age_class(x):
    if x > 60:
        age_class = 5
    elif x > 35 and x <= 60:
        age_class = 4
    elif x > 25 and x <= 35:
        age_class = 3
    elif x > 16 and x <= 25:
        age_class = 2
    else:
        age_class = 1
    return age_class

# %%
# ANSWER
titanic['Age_class'] = titanic['Age'].apply(create_fare_class)
titanic.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
# 23           24         1       1
# 27           28         0       1
# 31           32         1       1
# 52           53         1       1
#
#                                                  Name     Sex        Age  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 6                             McCarthy, Mr. Timothy J    male  54.000000
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.000000
# 11                           Bonnell, Miss. Elizabeth  female  58.000000
# 21                              Beesley, Mr. Lawrence    male  34.000000
# 23                       Sloper, Mr. William Thompson    male  28.000000
# 27                     Fortune, Mr. Charles Alexander    male  19.000000
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female  34.611765
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.000000
#
#     SibSp  Parch    Ticket      Fare        Cabin Embarked Cabin_class  \
# 1       1      0  PC 17599   71.2833          C85        C           C
# 3       1      0    113803   53.1000         C123        S           C
# 6       0      0     17463   51.8625          E46        S           E
# 10      1      1   PP 9549   16.7000           G6        S           G
# 11      0      0    113783   26.5500         C103        S           C
# 21      0      0    248698   13.0000          D56        S           D
# 23      0      0    113788   35.5000           A6        S           A
# 27      3      2     19950  263.0000  C23 C25 C27        S           C
# 31      1      0  PC 17569  146.5208          B78        C           B
# 52      1      0  PC 17572   76.7292          D33        C           D
#
#     Cabin_transformed  Fare_class  Age_class
# 1                 3.0           1          1
# 3                 3.0           1          1
# 6                 5.0           1          1
# 10                7.0           3          4
# 11                3.0           2          1
# 21                4.0           3          1
# 23                1.0           1          2
# 27                3.0           1          3
# 31                2.0           1          1
# 52                4.0           1          1

# %% [markdown]
# # Statistical Overview

# %% [markdown]
# ## Correlation
#
# Find correlation between `survived` and other features.

# %%
titanic.dtypes
# Out:
# PassengerId            int64
# Survived               int64
# Pclass                 int64
# Name                  object
# Sex                   object
# Age                  float64
# SibSp                  int64
# Parch                  int64
# Ticket                object
# Fare                 float64
# Cabin                 object
# Embarked              object
# Cabin_class           object
# Cabin_transformed    float64
# Fare_class             int64
# Age_class              int64
# dtype: object

# %%
# ANSWER
# Drop non-numeric columns
titanic_numeric = titanic.select_dtypes(include='number')
titanic_numeric
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  \
# 1              2         1       1  38.0      1      0  71.2833
# 3              4         1       1  35.0      1      0  53.1000
# 6              7         0       1  54.0      0      0  51.8625
# 10            11         1       3   4.0      1      1  16.7000
# 11            12         1       1  58.0      0      0  26.5500
# ..           ...       ...     ...   ...    ...    ...      ...
# 871          872         1       1  47.0      1      1  52.5542
# 872          873         0       1  33.0      0      0   5.0000
# 879          880         1       1  56.0      0      1  83.1583
# 887          888         1       1  19.0      0      0  30.0000
# 889          890         1       1  26.0      0      0  30.0000
#
#      Cabin_transformed  Fare_class  Age_class
# 1                  3.0           1          1
# 3                  3.0           1          1
# 6                  5.0           1          1
# 10                 7.0           3          4
# 11                 3.0           2          1
# ..                 ...         ...        ...
# 871                4.0           1          1
# 872                2.0           4          1
# 879                3.0           1          1
# 887                2.0           2          3
# 889                3.0           2          2
#
# [202 rows x 10 columns]

# %%
titanic_numeric.corr()
# Out:
#                    PassengerId  Survived    Pclass       Age     SibSp  \
# PassengerId           1.000000  0.111985 -0.084147  0.034659 -0.081137
# Survived              0.111985  1.000000 -0.030513 -0.253304  0.138202
# Pclass               -0.084147 -0.030513  1.000000 -0.318991 -0.086972
# Age                   0.034659 -0.253304 -0.318991  1.000000 -0.166415
# SibSp                -0.081137  0.138202 -0.086972 -0.166415  1.000000
# Parch                -0.064538  0.042456  0.056288 -0.276051  0.262348
# Fare                  0.017465  0.128261 -0.311740 -0.088608  0.291777
# Cabin_transformed    -0.090473  0.025619  0.597775 -0.189665  0.029191
# Fare_class            0.068237 -0.169128  0.708505 -0.099972 -0.331872
# Age_class            -0.050198  0.151346  0.318534 -0.827856  0.188922
#
#                       Parch      Fare  Cabin_transformed  Fare_class  \
# PassengerId       -0.064538  0.017465          -0.090473    0.068237
# Survived           0.042456  0.128261           0.025619   -0.169128
# Pclass             0.056288 -0.311740           0.597775    0.708505
# Age               -0.276051 -0.088608          -0.189665   -0.099972
# SibSp              0.262348  0.291777           0.029191   -0.331872
# Parch              1.000000  0.384970           0.017803   -0.159048
# Fare               0.384970  1.000000          -0.299331   -0.457234
# Cabin_transformed  0.017803 -0.299331           1.000000    0.389152
# Fare_class        -0.159048 -0.457234           0.389152    1.000000
# Age_class          0.357024  0.051990           0.176364    0.065338
#
#                    Age_class
# PassengerId        -0.050198
# Survived            0.151346
# Pclass              0.318534
# Age                -0.827856
# SibSp               0.188922
# Parch               0.357024
# Fare                0.051990
# Cabin_transformed   0.176364
# Fare_class          0.065338
# Age_class           1.000000

# %% [markdown]
# # [BONUS] Hypothesis Testing
# ---
# The usual process of null hypothesis testing consists of four steps.
#
# 1. Formulate the null hypothesis H_0 (commonly, that the observations are the result of pure chance) and the alternative hypothesis H_a (commonly, that the observations show a real effect combined with a component of chance variation).
#
# 2. Identify a test statistic that can be used to assess the truth of the null hypothesis.
#
# 3. Compute the p-value, which is the probability that a test statistic at least as significant as the one observed would be obtained assuming that the null hypothesis were true. The smaller the p-value, the stronger the evidence against the null hypothesis.
#
# 4. Compare the p-value to an acceptable significance value alpha (sometimes called an alpha value). If p<=alpha, that the observed effect is statistically significant, the null hypothesis is ruled out, and the alternative hypothesis is valid.

# %% [markdown]
# ### Define Hypothesis
#
# > Formulate the null hypothesis H_0 (commonly, that the observations are the result of pure chance) and the alternative hypothesis H_a (commonly, that the observations show a real effect combined with a component of chance variation).
#
#     Null Hypothesis (H0): There is no difference in the survival rate between the young and old passengers.
#
#     Alternative Hypothesis (HA): There is a difference in the survival rate between the young and old passengers.

# %% [markdown]
# ### Collect Data
#
# Next step is to collect data for each population group.
#
# Collect two sets of data, one with passengers who survived and another one with passengers who died (call them `titanic_survived` and `titanic_died`). The sample sizes should ideally be the same but they can be different. Let's say that the sample sizes are 100.

# %%
titanic['Survived'].value_counts()
# Out:
# Survived
# 1    134
# 0     68
# Name: count, dtype: int64

# %%
N=100
# ANSWER

titanic_survived = titanic[titanic['Survived'] == 1].sample(N)
titanic_died = titanic[titanic['Survived'] == 0]

# %%
a = titanic_survived['Age']
b = titanic_died['Age']

# %% [markdown]
# ### Set alpha (let alpha = 0.05)

# %%
# ANSWER
alpha = 0.05

# %% [markdown]
# ### Calculate test statistic
#
# > Here we identify a test statistic that can be used to assess the truth of the null hypothesis.

# %%
## Calculate the variance to get the standard deviation
var_a = a.var(ddof = 1)
var_b = b.var(ddof = 1)

## Calculate the Standard Deviation
s = np.sqrt((var_a + var_b)/2)

# %%
## Calculate the t-statistic
t = (a.mean() - b.mean())/(s*np.sqrt(2/N))

# %% [markdown]
# ### Find the p-value
#
# > Next we compute the P-value, which is the probability that a test statistic at least as significant as the one observed would be obtained assuming that the null hypothesis were true. The smaller the P-value, the stronger the evidence against the null hypothesis.

# %%
import scipy.stats as stats

# %%
## Compare with the critical t-value
## Degrees of freedom
df = 2*N - 2

#p-value after comparison with the t
if (t > 0):
    p = 2*(1 - stats.t.cdf(t, df = df))
else:
    p = 2*stats.t.cdf(t, df = df)

# %%
print("t = " + str(t))
print("p = " + str(p))
# Out:
# t = -4.191477193796581
# p = 4.1749515495414465e-05

# %% [markdown]
# ### Interpret results
#
# > The p-value is compared to an acceptable significance value  alpha (sometimes called an alpha value). If p<=alpha, then the observed effect is statistically significant, the null hypothesis is ruled out, and the alternative hypothesis is valid.

# %%
def print_sig(p_value, alpha):
    if p_value < alpha:
        print("We reject our null hypothesis.")
    else:
        print("We fail to reject our null hypothesis.")

# %%
## Cross Checking with the internal scipy function
t2, p2 = stats.ttest_ind(a,b)
print("t = " + str(t2))
print("p = " + str(p2))

print_sig(p2, alpha)
# Out:
# t = -3.7742033305697786
# p = 0.000223136696607587
# We reject our null hypothesis.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2023 Institute of Data
#
#
# ---
#
#
#
# ---
